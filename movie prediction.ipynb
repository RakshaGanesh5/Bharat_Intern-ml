# %% [markdown]
# # MOVIE PREDICTION

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Indian_movies[1].csv")
data
# Out:
#      Unnamed: 0  Rank                          Movie Names  \
# 0             0     1  Ramayana: The Legend of Prince Rama
# 1             1     2           Rocketry: The Nambi Effect
# 2             2     3                              Nayakan
# 3             3     4                             Gol Maal
# 4             4     5                           Anbe Sivam
# ..          ...   ...                                  ...
# 245         245   246                           Kai Po Che
# 246         246   247                       Poove Unakkaga
# 247         247   248                                Raazi
# 248         248   249                          Dasvidaniya
# 249         249   250                                  Dia
#
#                                                  Links  Rating  Year  \
# 0    https://www.imdb.com//title/tt0259534/?ref_=fe...     9.2  1993
# 1    https://www.imdb.com//title/tt9263550/?ref_=fe...     8.7  2022
# ...

# %%
data=data.drop("Unnamed: 0",axis=1)
data
# Out:
#      Rank                          Movie Names  \
# 0       1  Ramayana: The Legend of Prince Rama
# 1       2           Rocketry: The Nambi Effect
# 2       3                              Nayakan
# 3       4                             Gol Maal
# 4       5                           Anbe Sivam
# ..    ...                                  ...
# 245   246                           Kai Po Che
# 246   247                       Poove Unakkaga
# 247   248                                Raazi
# 248   249                          Dasvidaniya
# 249   250                                  Dia
#
#                                                  Links  Rating  Year  \
# 0    https://www.imdb.com//title/tt0259534/?ref_=fe...     9.2  1993
# 1    https://www.imdb.com//title/tt9263550/?ref_=fe...     8.7  2022
# 2    https://www.imdb.com//title/tt0093603/?ref_=fe...     8.6  1987
# 3    https://www.imdb.com//title/tt0079221/?ref_=fe...     8.5  1979
# ...

# %%
data=data.drop("Links",axis=1)
data
# Out:
#      Rank                          Movie Names  Rating  Year  \
# 0       1  Ramayana: The Legend of Prince Rama     9.2  1993
# 1       2           Rocketry: The Nambi Effect     8.7  2022
# 2       3                              Nayakan     8.6  1987
# 3       4                             Gol Maal     8.5  1979
# 4       5                           Anbe Sivam     8.6  2003
# ..    ...                                  ...     ...   ...
# 245   246                           Kai Po Che     7.8  2013
# 246   247                       Poove Unakkaga     8.6  1996
# 247   248                                Raazi     7.7  2018
# 248   249                          Dasvidaniya     7.8  2008
# 249   250                                  Dia     8.0  2020
#
#     Duration_of_movie                                  Genere  \
# 0                  PG  Animation,Action,Adventure,Back to top
# 1              2h 37m             Biography,Drama,Back to top
# ...

# %%
data.isnull().sum()
# Out:
# Rank                 0
# Movie Names          0
# Rating               0
# Year                 0
# Duration_of_movie    0
# Genere               0
# Description          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               250 non-null    int64
#  1   Movie Names        250 non-null    object
#  2   Rating             250 non-null    float64
#  3   Year               250 non-null    int64
#  4   Duration_of_movie  250 non-null    object
#  5   Genere             250 non-null    object
#  6   Description        250 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 13.8+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

x = data['Duration_of_movie']
data['Duration_of_movie'] = le.fit_transform(x)
data

y = data['Genere']
data['Genere'] = le.fit_transform(y)

z = data['Description']
data['Description'] = le.fit_transform(z)
data
# Out:
#      Rank                          Movie Names  Rating  Year  \
# 0       1  Ramayana: The Legend of Prince Rama     9.2  1993
# 1       2           Rocketry: The Nambi Effect     8.7  2022
# 2       3                              Nayakan     8.6  1987
# 3       4                             Gol Maal     8.5  1979
# 4       5                           Anbe Sivam     8.6  2003
# ..    ...                                  ...     ...   ...
# 245   246                           Kai Po Che     7.8  2013
# 246   247                       Poove Unakkaga     8.6  1996
# 247   248                                Raazi     7.7  2018
# 248   249                          Dasvidaniya     7.8  2008
# 249   250                                  Dia     8.0  2020
#
#      Duration_of_movie  Genere  Description
# 0                   41      24          108
# 1                   21      26          128
# 2                   40      42           16
# 3                   40      41           46
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               250 non-null    int64
#  1   Movie Names        250 non-null    object
#  2   Rating             250 non-null    float64
#  3   Year               250 non-null    int64
#  4   Duration_of_movie  250 non-null    int32
#  5   Genere             250 non-null    int32
#  6   Description        250 non-null    int32
# dtypes: float64(1), int32(3), int64(2), object(1)
# memory usage: 10.9+ KB

# %%
data.describe()
# Out:
#              Rank      Rating        Year  Duration_of_movie      Genere  \
# count  250.000000  250.000000   250.00000          250.00000  250.000000
# mean   125.500000    8.182000  2007.97600           35.63200   31.784000
# std     72.312977    0.263198    14.66546           10.51565   17.784106
# min      1.000000    7.700000  1955.00000            0.00000    0.000000
# 25%     63.250000    8.000000  2003.00000           40.00000   13.000000
# 50%    125.500000    8.100000  2013.00000           40.00000   32.000000
# 75%    187.750000    8.300000  2018.00000           40.00000   45.000000
# max    250.000000    9.200000  2023.00000           47.00000   67.000000
#
#        Description
# count   250.000000
# mean    124.500000
# std      72.312977
# min       0.000000
# 25%      62.250000
# 50%     124.500000
# 75%     186.750000
# max     249.000000

# %%
data.corr()
# Out:
# C:\Users\raksh\AppData\Local\Temp\ipykernel_11744\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                        Rank    Rating      Year  Duration_of_movie    Genere  \
# Rank               1.000000 -0.777771  0.127249          -0.099517  0.019996
# Rating            -0.777771  1.000000 -0.101973          -0.060155 -0.004609
# Year               0.127249 -0.101973  1.000000          -0.122297 -0.098708
# Duration_of_movie -0.099517 -0.060155 -0.122297           1.000000 -0.117422
# Genere             0.019996 -0.004609 -0.098708          -0.117422  1.000000
# Description       -0.026102  0.094501 -0.041103           0.040920  0.019324
#
#                    Description
# Rank                 -0.026102
# Rating                0.094501
# Year                 -0.041103
# ...

# %%
sns.heatmap(data.corr(),annot=True,fmt='0.1f')
# Out:
# C:\Users\raksh\AppData\Local\Temp\ipykernel_11744\1758918653.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,fmt='0.1f')
# <Axes: >

# %%
sns.countplot(data=data,x="Rank")
# Out:
# <Axes: xlabel='Rank', ylabel='count'>

# %%
sns.countplot(data=data,x="Rating")
# Out:
# <Axes: xlabel='Rating', ylabel='count'>

# %%
sns.barplot(data=data,x="Rating",y="Rank",hue="Year")
# Out:
# <Axes: xlabel='Rating', ylabel='Rank'>

# %%
data.shape
# Out:
# (250, 7)

# %%
df=data["Rating"].value_counts()
df.plot(kind='pie')
# Out:
# <Axes: ylabel='Rating'>

# %%
df=data["Rank"].value_counts()
df.plot(kind='pie')
# Out:
# <Axes: ylabel='Rank'>

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
data["Genere"]=LE.fit_transform(data["Genere"])
data["Description"]=LE.fit_transform(data["Description"])

# %%
data.head()
# Out:
#    Rank                          Movie Names  Rating  Year  Duration_of_movie  \
# 0     1  Ramayana: The Legend of Prince Rama     9.2  1993                 41
# 1     2           Rocketry: The Nambi Effect     8.7  2022                 21
# 2     3                              Nayakan     8.6  1987                 40
# 3     4                             Gol Maal     8.5  1979                 40
# 4     5                           Anbe Sivam     8.6  2003                 40
#
#    Genere  Description
# 0      24          108
# 1      26          128
# 2      42           16
# 3      41           46
# 4      22          229

# %%
x = data.drop("Movie Names", axis=1)


y = data["Movie Names"]

# %%
x.head()
# Out:
#    Rank  Rating  Year  Duration_of_movie  Genere  Description
# 0     1     9.2  1993                 41      24          108
# 1     2     8.7  2022                 21      26          128
# 2     3     8.6  1987                 40      42           16
# 3     4     8.5  1979                 40      41           46
# 4     5     8.6  2003                 40      22          229

# %%
y.head()
# Out:
# 0    Ramayana: The Legend of Prince Rama
# 1             Rocketry: The Nambi Effect
# 2                                Nayakan
# 3                               Gol Maal
# 4                             Anbe Sivam
# Name: Movie Names, dtype: object

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=20)
xtrain.shape,xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((200, 6), (50, 6), (200,), (50,))

# %%
ytrain.head()
# Out:
# 133    Dilwale Dulhania Le Jayenge
# 122                      Charulata
# 98                 Rang De Basanti
# 155                        Padosan
# 233                   Mother India
# Name: Movie Names, dtype: object

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
from sklearn.preprocessing import LabelEncoder


label_encoder = LabelEncoder()
ytrain_encoded = label_encoder.fit_transform(ytrain)


lr.fit(xtrain, ytrain_encoded)
# Out:
# LinearRegression()

# %%
ypred=lr.predict(xtest)
ypred[:5]
# Out:
# array([114.57094924,  98.47241043,  98.38521428,  87.84789711,
#         92.2655739 ])

# %%
ytest[:5]
# Out:
# 58              Chithram
# 13          Black Friday
# 121    Bajrangi Bhaijaan
# 28            Visaaranai
# 210              Airlift
# Name: Movie Names, dtype: object

# %%
label_encoder = LabelEncoder()
ytest_encoded = label_encoder.fit_transform(ytest)

accuracy = lr.score(xtest, ytest_encoded)
accuracy
# Out:
# -27.30380261830706

# %%
import pickle as pkl
filename = "save_model.sav"
pkl.dump(lr, open(filename, 'wb'))

# %%
pip install gradio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pickle as pkl
filename="data.sav"
pkl.dump(lr,open(filename,'bw'))

# %%
loaded_model=pkl.load(open(filename,'br'))
loaded_model
# Out:
# LinearRegression()

# %%
import gradio as gr

# %%
def Movie_Names(Rank, Rating, Year, Duration_of_movie, Genere, Description):
    # Create an array with the input features
    x = np.array([Rank, Rating, Year, Duration_of_movie, Genere, Description])

    # Reshape the array to match the input shape expected by the model
    x = x.reshape(1, -1)

    # Make a prediction using the logistic regression model
    prediction = lr.predict(x)

    # Assuming 'lr' is a classifier, you might want to convert the prediction to a label
    label = str(prediction[0])  # Convert the prediction to a string label

    return label

# %%
app = gr.Interface(
    fn=Movie_Names,
    inputs=[
        gr.inputs.Number(label="Rank"),
        gr.inputs.Number(label="Rating"),
        gr.inputs.Number(label="Year"),
        gr.inputs.Number(label="Duration_of_movie"),
        gr.inputs.Number(label="Genere"),
        gr.inputs.Number(label="Description"),  
    ],
    outputs=gr.outputs.Textbox(),  # Use Textbox for string output
    title="Developing an ML Model for Movie Recommendation",
)
# Out:
# C:\Users\raksh\anaconda3\lib\site-packages\gradio\inputs.py:59: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# C:\Users\raksh\anaconda3\lib\site-packages\gradio\deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# C:\Users\raksh\anaconda3\lib\site-packages\gradio\outputs.py:22: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   warnings.warn(

# %%
app.launch(show_error=True)
# Out:
# Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# C:\Users\raksh\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
app.close()
# Out:
# Closing server running on port: 7861

# %%
filename = "save_model.sav"
pkl.dump(lr, open(filename, 'wb'))
